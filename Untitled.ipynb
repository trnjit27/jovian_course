# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fifa_df = pd.read_csv('FIFA-21 Complete.csv', sep = ";")

# %%
fifa_df
# Out:
#        player_id               name  nationality  position  overall  age  \
# 0         158023       Lionel Messi    Argentina  ST|CF|RW       94   33
# 1          20801  Cristiano Ronaldo     Portugal     ST|LW       93   35
# 2         190871          Neymar Jr       Brazil    CAM|LW       92   28
# 3         203376    Virgil van Dijk  Netherlands        CB       91   29
# 4         200389          Jan Oblak     Slovenia        GK       91   27
# ...          ...                ...          ...       ...      ...  ...
# 17976     256093        Jaime Ortíz      Ecuador        ST       56   21
# 17977     256088   Michael Carcelén      Ecuador        CM       56   23
# 17978     256074        Davide Luzi    Venezuela        ST       56   18
# 17979     256073    Sergio Sulbarán    Venezuela        RW       56   22
# 17980     256072          Luis Peña    Venezuela        CM       56   18
#
#        hits  potential                         team
# ...

# %%
fifa_df.shape
# Out:
# (17981, 9)

# %%
fifa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17981 entries, 0 to 17980
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   player_id    17981 non-null  int64
#  1   name         17981 non-null  object
#  2   nationality  17981 non-null  object
#  3   position     17981 non-null  object
#  4   overall      17981 non-null  int64
#  5   age          17981 non-null  int64
#  6   hits         17981 non-null  int64
#  7   potential    17981 non-null  int64
#  8   team         17981 non-null  object
# dtypes: int64(5), object(4)
# memory usage: 1.2+ MB

# %%
fifa_df.describe()
# Out:
#            player_id       overall           age          hits     potential
# count   17981.000000  17981.000000  17981.000000  17981.000000  17981.000000
# mean   220912.660531     67.274345     26.311440      2.689450     71.738057
# std     27738.072671      5.924392      4.556077     10.846286      5.961968
# min        41.000000     56.000000     17.000000      0.000000     57.000000
# 25%    204881.000000     63.000000     23.000000      0.000000     67.000000
# 50%    226753.000000     67.000000     26.000000      0.000000     71.000000
# 75%    241587.000000     71.000000     30.000000      2.000000     76.000000
# max    256469.000000     94.000000     43.000000    371.000000     95.000000

# %%
type(fifa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
fifa_df.columns
# Out:
# Index(['player_id', 'name', 'nationality', 'position', 'overall', 'age',
#        'hits', 'potential', 'team'],
#       dtype='object')

# %%
type(fifa_df.overall)
# Out:
# pandas.core.series.Series

# %%
fifa_df['name']
# Out:
# 0             Lionel Messi
# 1        Cristiano Ronaldo
# 2                Neymar Jr
# 3          Virgil van Dijk
# 4                Jan Oblak
#                ...
# 17976          Jaime Ortíz
# 17977     Michael Carcelén
# 17978          Davide Luzi
# 17979      Sergio Sulbarán
# 17980            Luis Peña
# Name: name, Length: 17981, dtype: object

# %%
fifa_df['name'][20]
# Out:
# 'Manuel Neuer'

# %%
fifa_df.at[10,'name']
# Out:
# 'Sadio Mané'

# %%
fifa_df.at[10,'overall']
# Out:
# 90

# %%
fifa_df.head(10)
# Out:
#    player_id                name  nationality  position  overall  age  hits  \
# 0     158023        Lionel Messi    Argentina  ST|CF|RW       94   33   299
# 1      20801   Cristiano Ronaldo     Portugal     ST|LW       93   35   276
# 2     190871           Neymar Jr       Brazil    CAM|LW       92   28   186
# 3     203376     Virgil van Dijk  Netherlands        CB       91   29   127
# 4     200389           Jan Oblak     Slovenia        GK       91   27    47
# 5     192985     Kevin De Bruyne      Belgium    CM|CAM       91   29   119
# 6     188545  Robert Lewandowski       Poland        ST       91   31    89
# 7     183277         Eden Hazard      Belgium     ST|LW       91   29    66
# 8     212831             Alisson       Brazil        GK       90   27    53
# 9     209331       Mohamed Salah        Egypt     ST|RW       90   28    94
#
#    potential                  team
# 0         94         FC Barcelona
# 1         93             Juventus
# ...

# %%
fifa_df.tail(10)
# Out:
#        player_id              name    nationality   position  overall  age  \
# 17971     256170      Samuel Renel         France  RM|CM|CAM       56   18
# 17972     256150   Winston Ramírez       Colombia         RB       56   19
# 17973     256148   Joseph Espinoza        Ecuador        CDM       56   20
# 17974     256129    Zakaria Atteri        Morocco     CM|CAM       56   19
# 17975     256101  Patrick Seagrist  United States         LB       56   22
# 17976     256093       Jaime Ortíz        Ecuador         ST       56   21
# 17977     256088  Michael Carcelén        Ecuador         CM       56   23
# 17978     256074       Davide Luzi      Venezuela         ST       56   18
# 17979     256073   Sergio Sulbarán      Venezuela         RW       56   22
# 17980     256072         Luis Peña      Venezuela         CM       56   18
#
#        hits  potential                             team
# 17971     0         72  Chamois Niortais Football Club
# ...

# %%
fifa_df.isna().sum()
# Out:
# player_id      0
# name           0
# nationality    0
# position       0
# overall        0
# age            0
# hits           0
# potential      0
# team           0
# dtype: int64

# %%
fifa_df.nationality.nunique()
# Out:
# 162

# %%
highest_rating_df = fifa_df.sort_values('overall', ascending = False).head(10)

# %%
highest_rating_df
# Out:
#     player_id                   name  nationality  position  overall  age  \
# 0      158023           Lionel Messi    Argentina  ST|CF|RW       94   33
# 1       20801      Cristiano Ronaldo     Portugal     ST|LW       93   35
# 2      190871              Neymar Jr       Brazil    CAM|LW       92   28
# 3      203376        Virgil van Dijk  Netherlands        CB       91   29
# 4      200389              Jan Oblak     Slovenia        GK       91   27
# 5      192985        Kevin De Bruyne      Belgium    CM|CAM       91   29
# 6      188545     Robert Lewandowski       Poland        ST       91   31
# 7      183277            Eden Hazard      Belgium     ST|LW       91   29
# 11     192448  Marc-André ter Stegen      Germany        GK       90   28
# 12     153079          Sergio Agüero    Argentina        ST       90   32
#
#     hits  potential                  team
# 0    299         94         FC Barcelona
# 1    276         93             Juventus
# ...

# %%
lowest_rating_df = fifa_df.sort_values('overall', ascending = False).tail(10)

# %%
lowest_rating_df
# Out:
#        player_id                name   nationality   position  overall  age  \
# 17966     256417          Mads Sande        Norway         CM       56   22
# 17971     256170        Samuel Renel        France  RM|CM|CAM       56   18
# 17970     256263   Dmitry Markitesov        Russia   CB|RM|LM       56   19
# 17969     256314         Gautier Ott        France         ST       56   18
# 17968     256326      Paulos Abraham        Sweden      RW|LW       56   18
# 17967     256329  Hassan Al Shamrani  Saudi Arabia     CB|CDM       56   29
# 17965     256436      Erland Tangvik        Norway         GK       56   23
# 17964     256445              Ruvira         Spain         GK       56   20
# 17963     256469  Juan Camilo Suárez      Colombia         CB       56   21
# 17980     256072           Luis Peña     Venezuela         CM       56   18
#
#        hits  potential                             team
# 17966     0         63                    FK Haugesund
# ...

# %%
fifa_df.loc[10]
# Out:
# player_id          208722
# name           Sadio Mané
# nationality       Senegal
# position               LW
# overall                90
# age                    28
# hits                   76
# potential              90
# team           Liverpool
# Name: 10, dtype: object

# %%
fifa_df.loc[10:17]
# Out:
#     player_id                   name nationality  position  overall  age  \
# 10     208722             Sadio Mané     Senegal        LW       90   28
# 11     192448  Marc-André ter Stegen     Germany        GK       90   28
# 12     153079          Sergio Agüero   Argentina        ST       90   32
# 13     231747          Kylian Mbappé      France  ST|RW|LW       89   21
# 14     215914           N'Golo Kanté      France    CDM|CM       89   29
# 15     202126             Harry Kane     England        ST       89   27
# 16     194765      Antoine Griezmann      France  ST|CF|LW       89   29
# 17     182521             Toni Kroos     Germany        CM       89   30
#
#     hits  potential                  team
# 10    76         90            Liverpool
# 11    68         93         FC Barcelona
# 12    50         90      Manchester City
# 13   222         95  Paris Saint-Germain
# 14    75         89              Chelsea
# 15    64         91    Tottenham Hotspur
# ...

# %%
fifa_df.team.nunique()
# Out:
# 713

# %%
fifa_df.name.count()
# Out:
# 17981

# %%
fifa_df.position.nunique()
# Out:
# 232

# %%
fifa_df.position.value_counts()
# Out:
# CB              2296
# GK              1884
# ST              1757
# CDM|CM          1546
# LB               695
#                 ...
# RB|LWB|LW          1
# LB|RW              1
# RB|CDM|RW          1
# LB|RM|CM           1
# LWB|RM|RW|LW       1
# Name: position, Length: 232, dtype: int64

# %%
fifa_df['position']
# Out:
# 0        ST|CF|RW
# 1           ST|LW
# 2          CAM|LW
# 3              CB
# 4              GK
#            ...
# 17976          ST
# 17977          CM
# 17978          ST
# 17979          RW
# 17980          CM
# Name: position, Length: 17981, dtype: object

# %%
high_cb_df = fifa_df[fifa_df['position'] == 'CB'][['name', 'nationality', 'overall', 'age', 'team']].head(10)

# %%
high_cb_df
# Out:
#                  name  nationality  overall  age                  team
# 3     Virgil van Dijk  Netherlands       91   29            Liverpool
# 21       Sergio Ramos        Spain       89   34          Real Madrid
# 25  Kalidou Koulibaly      Senegal       88   29               Napoli
# 33              Piqué        Spain       88   33         FC Barcelona
# 34  Giorgio Chiellini        Italy       88   35             Juventus
# 37    Aymeric Laporte       France       87   26      Manchester City
# 49        Diego Godín      Uruguay       87   34                Inter
# 50       Mats Hummels      Germany       87   31    Borussia Dortmund
# 54       Thiago Silva       Brazil       87   35  Paris Saint-Germain
# 56     Milan Škriniar     Slovakia       86   25                Inter

# %%
high_gk_df = fifa_df[fifa_df['position'] == 'GK'][['name', 'nationality', 'overall', 'age', 'team']].head(10)

# %%
high_gk_df
# Out:
#                      name nationality  overall  age                  team
# 4               Jan Oblak    Slovenia       91   27      Atlético Madrid
# 8                 Alisson      Brazil       90   27            Liverpool
# 11  Marc-André ter Stegen     Germany       90   28         FC Barcelona
# 20           Manuel Neuer     Germany       89   34    FC Bayern München
# 22                Ederson      Brazil       88   26      Manchester City
# 27                 De Gea       Spain       88   29    Manchester United
# 28       Thibaut Courtois     Belgium       88   28          Real Madrid
# 32       Samir Handanovic    Slovenia       88   36                Inter
# 42           Keylor Navas  Costa Rica       87   33  Paris Saint-Germain
# 47      Wojciech Szczesny      Poland       87   30             Juventus

# %%
high_st_df = fifa_df[fifa_df['position'] == 'ST'][['name', 'nationality', 'overall', 'age', 'team']].head(10)

# %%
high_st_df
# Out:
#                   name nationality  overall  age                  team
# 6   Robert Lewandowski      Poland       91   31    FC Bayern München
# 12       Sergio Agüero   Argentina       90   32      Manchester City
# 15          Harry Kane     England       89   27    Tottenham Hotspur
# 19         Luis Suárez     Uruguay       89   33         FC Barcelona
# 43       Ciro Immobile       Italy       87   30                Lazio
# 62         Timo Werner     Germany       86   24           RB Leipzig
# 64         Jamie Vardy     England       86   33       Leicester City
# 69        Mauro Icardi   Argentina       86   27  Paris Saint-Germain
# 72       Romelu Lukaku     Belgium       86   27                Inter
# 78      Edinson Cavani     Uruguay       86   33  Paris Saint-Germain

# %%
high_rb_df = fifa_df[fifa_df['position'] == 'RB'][['name', 'nationality', 'overall', 'age', 'team']].head(10)

# %%
high_rb_df
# Out:
#                        name nationality  overall  age                team
# 83   Trent Alexander-Arnold     England       85   21          Liverpool
# 94                 Carvajal       Spain       85   28        Real Madrid
# 123         Ricardo Pereira    Portugal       84   26     Leicester City
# 207             Kyle Walker     England       83   30    Manchester City
# 238           Nélson Semedo    Portugal       82   26       FC Barcelona
# 261            João Cancelo    Portugal       82   26    Manchester City
# 362     Alessandro Florenzi       Italy       81   29        Valencia CF
# 389         Kieran Trippier     England       81   29    Atlético Madrid
# 486           Šime Vrsaljko     Croatia       80   28    Atlético Madrid
# 569               Odriozola       Spain       79   24  FC Bayern München

# %%
high_lb_df = fifa_df[fifa_df['position'] == 'LB'][['name', 'nationality', 'overall', 'age', 'team']].head(10)

# %%
high_lb_df
# Out:
#                    name nationality  overall  age             team
# 60     Andrew Robertson    Scotland       86   26       Liverpool
# 74           Jordi Alba       Spain       86   31    FC Barcelona
# 121         Alex Telles      Brazil       84   27        FC Porto
# 151             Marcelo      Brazil       84   32     Real Madrid
# 172  Nicolás Tagliafico   Argentina       83   27            Ajax
# 175            Grimaldo       Spain       83   24      SL Benfica
# 192         Lucas Digne      France       83   27         Everton
# 292  Aleksandar Kolarov      Serbia       82   34            Roma
# 326        Ben Chilwell     England       81   23  Leicester City
# 329       Ferland Mendy      France       81   25     Real Madrid

# %%
high_cm_df = fifa_df[fifa_df['position'] == 'CM'][['name', 'nationality', 'overall', 'age', 'team']].head(10)

# %%
high_cm_df
# Out:
#                 name  nationality  overall  age                      team
# 17        Toni Kroos      Germany       89   30              Real Madrid
# 18       Luka Modric      Croatia       89   34              Real Madrid
# 45            Parejo        Spain       87   31              Valencia CF
# 57   Frenkie de Jong  Netherlands       86   23             FC Barcelona
# 84            Arthur       Brazil       85   23             FC Barcelona
# 111     Ivan Rakitic      Croatia       85   32             FC Barcelona
# 127    Mateo Kovacic      Croatia       84   26                  Chelsea
# 131            Allan       Brazil       84   29                   Napoli
# 155    João Moutinho     Portugal       84   33  Wolverhampton Wanderers
# 161           Fabián        Spain       83   24                   Napoli

# %%
high_cdm_df = fifa_df[fifa_df['position'] == 'CDM'][['name', 'nationality', 'overall', 'age', 'team']].head(10)

# %%
high_cdm_df
# Out:
#                        name nationality  overall  age  \
# 26                 Casemiro      Brazil       88   28
# 29          Sergio Busquets       Spain       88   32
# 63                  Fabinho      Brazil       86   26
# 152             Lucas Leiva      Brazil       84   33
# 453           Matias Vecino     Uruguay       80   28
# 479        Taras Stepanenko     Ukraine       80   30
# 583          Melvin Parrela      Brazil       79   20
# 929   Julian Baumgartlinger     Austria       78   32
# 990   Leandro Agustín Baezo     Uruguay       77   32
# 1038         Rodrigo Vuarte      Brazil       77   28
#
#                            team
# 26                 Real Madrid
# 29                FC Barcelona
# 63                   Liverpool
# 152                      Lazio
# 453                      Inter
# 479           Shakhtar Donetsk
# 583   Centro Sportivo Alagoano
# 929        Bayer 04 Leverkusen
# 990                Free Agents
# 1038                 São Paulo

# %%
high_cam_df = fifa_df[fifa_df['position'] == 'CAM'][['name', 'nationality', 'overall', 'age', 'team']].head(10)

# %%
high_cam_df
# Out:
#                         name nationality  overall  age  \
# 391                 Giuliano      Brazil       81   30
# 466   Juan Fernando Quintero    Colombia       80   27
# 636           Florent Mollet      France       79   28
# 708           Nicolás Gaitán   Argentina       79   32
# 886           Gastón Ramírez     Uruguay       78   29
# 993                Chiquinho    Portugal       77   25
# 1034          Adilson Edrada      Brazil       77   28
# 1434           Albert Rusnák    Slovakia       76   26
# 1777                    Kaku    Paraguay       75   25
# 1920               Tom Rogic   Australia       75   27
#
#                          team
# 391                 Al Nassr
# 466              River Plate
# 636   Montpellier Hérault SC
# 708               LOSC Lille
# 886                Sampdoria
# 993               SL Benfica
# 1034                  Santos
# 1434          Real Salt Lake
# 1777      New York Red Bulls
# 1920                  Celtic

# %%
fifa_df[fifa_df['overall'] > 80].count()
# Out:
# player_id      411
# name           411
# nationality    411
# position       411
# overall        411
# age            411
# hits           411
# potential      411
# team           411
# dtype: int64

# %%
fifa_df[fifa_df['overall'] > 90].count()
# Out:
# player_id      8
# name           8
# nationality    8
# position       8
# overall        8
# age            8
# hits           8
# potential      8
# team           8
# dtype: int64

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian

# %%
jovian.commit(project = 'fifa-21-data-course-project')
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Please enter your API key ( from https://jovian.ml/ ):
# API KEY:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.8/site-packages/click/termui.py in prompt_func(text)
#     128             echo(text, nl=False, err=err)
# --> 129             return f("")
#     130         except (KeyboardInterrupt, EOFError):
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/click/termui.py in hidden_prompt_func(prompt)
#      53
# ---> 54     return getpass.getpass(prompt)
#      55
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#     842                     UserWarning, stacklevel=2)
# --> 843         return self._input_request(prompt,
#     844             self._parent_ident,
#
# ...

# %%
fifa_mean_df = fifa_df.groupby('team')[['overall', 'age']].mean()

# %%
fifa_mean_df
# Out:
#                           overall        age
# team
# 1. FC Heidenheim 1846   68.208333  25.958333
# 1. FC Kaiserslautern    64.148148  25.000000
# 1. FC Köln              72.307692  25.769231
# 1. FC Magdeburg         64.083333  25.833333
# 1. FC Nürnberg          68.892857  26.214286
# ...                           ...        ...
# Zamora Fútbol Club      59.730769  24.884615
# spusu SKN St. Pölten    63.730769  25.961538
# Çaykur Rizespor         68.000000  26.192308
# Örebro SK               63.312500  26.812500
# Östersunds FK           61.904762  24.047619
#
# [713 rows x 2 columns]

# %%
fifa_age_df = fifa_df.sort_values('age', ascending = True).head(10)

# %%
fifa_age_df
# Out:
#        player_id                  name nationality position  overall  age  \
# 1637      248243     Eduardo Camavinga      France       CM       75   17
# 15008     253028     Gabriele Plechero       Italy       GK       61   17
# 14915     255339         Jayden Nelson      Canada    LM|LW       61   17
# 17075     253971    Tom Dickson-Peters    Scotland       ST       58   17
# 17066     254580         Elias Damergy     Tunisia       GK       58   17
# 17062     254653          Matías Arezo     Uruguay       ST       58   17
# 16430     255682           Lucas Greno     Uruguay       CB       59   17
# 17040     255151  Simon Ngapandouetnbu    Cameroon       GK       58   17
# 17035     255394          Fidel Ambríz      Mexico       CM       58   17
# 14928     255142    Santiago Cartagena     Uruguay   CDM|CM       61   17
#
#        hits  potential                             team
# 1637     94         86                Stade Rennais FC
# ...

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Please enter your API key ( from https://jovian.ml/ ):
# API KEY:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.8/site-packages/click/termui.py in prompt_func(text)
#     128             echo(text, nl=False, err=err)
# --> 129             return f("")
#     130         except (KeyboardInterrupt, EOFError):
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/click/termui.py in hidden_prompt_func(prompt)
#      53
# ---> 54     return getpass.getpass(prompt)
#      55
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#     842                     UserWarning, stacklevel=2)
# --> 843         return self._input_request(prompt,
#     844             self._parent_ident,
#
# ...

# %%
cr7 = fifa_df.loc[fifa_df['name'] == 'Cristiano Ronaldo']

# %%
cr7
# Out:
#    player_id               name nationality position  overall  age  hits  \
# 1      20801  Cristiano Ronaldo    Portugal    ST|LW       93   35   276
#
#    potential       team
# 1         93  Juventus

# %%
lm10 = fifa_df.loc[fifa_df['name'] == 'Lionel Messi']

# %%
lm10
# Out:
#    player_id          name nationality  position  overall  age  hits  \
# 0     158023  Lionel Messi   Argentina  ST|CF|RW       94   33   299
#
#    potential           team
# 0         94  FC Barcelona

# %%
fifa_df[fifa_df['nationality'] == 'India'][['name','overall','potential','position','hits','age','team']]
# Out:
#                        name  overall  potential position  hits  age  \
# 11885   Gajodara Chatterjee       64         64       GK     1   35
# 13068       Bhadrashree Raj       63         63       RB     1   32
# 13069          Prakul Bhatt       63         63       ST     3   35
# 14135     Anvit Swaminathan       62         62   LM|CAM     2   28
# 14136     Hantidev Bhandari       62         62    RM|LM     0   31
# 14137  Abhimoda Chakraborty       62         62       CB     0   34
# 15058       Devindra Pillai       61         61    RM|RW     0   32
# 15824      Anuvinda Khurana       60         62       CB     2   27
# 15825            Adit Ginti       60         62    LB|LM     3   26
# 15826        Remil Nadkarni       60         60   CAM|CF     1   34
# 15827         Bismeet Sidhu       60         60   CDM|CM     2   32
# 15828          Tapish Atwal       60         60       CB     0   36
# 15829      Attana Deshpande       60         60       LM     0   39
# ...

# %%
fifa_df
# Out:
#        player_id               name  nationality  position  overall  age  \
# 0         158023       Lionel Messi    Argentina  ST|CF|RW       94   33
# 1          20801  Cristiano Ronaldo     Portugal     ST|LW       93   35
# 2         190871          Neymar Jr       Brazil    CAM|LW       92   28
# 3         203376    Virgil van Dijk  Netherlands        CB       91   29
# 4         200389          Jan Oblak     Slovenia        GK       91   27
# ...          ...                ...          ...       ...      ...  ...
# 17976     256093        Jaime Ortíz      Ecuador        ST       56   21
# 17977     256088   Michael Carcelén      Ecuador        CM       56   23
# 17978     256074        Davide Luzi    Venezuela        ST       56   18
# 17979     256073    Sergio Sulbarán    Venezuela        RW       56   22
# 17980     256072          Luis Peña    Venezuela        CM       56   18
#
#        hits  potential                         team
# ...

# %%
top_countries = fifa_df['nationality'].value_counts().head(10)

# %%
top_countries
# Out:
# England        1496
# Germany        1138
# Spain          1055
# Argentina       970
# France          948
# Brazil          894
# Italy           637
# Colombia        561
# Japan           448
# Netherlands     418
# Name: nationality, dtype: int64

# %%
top_countries.plot.bar(color = 'orange')
plt.title('Most players from top 10 countries')
plt.xlabel('Country')
plt.ylabel('Number of players');

# %%
plt.hist(fifa_df.overall)
plt.title('Distribution of overall rating of players in FIFA 21')
plt.xlabel('Rating')
plt.ylabel('Number of Players');

# %%
plt.hist([fifa_df.overall, fifa_df.potential], alpha = 0.5, stacked = True)
plt.title('Distribution of overall rating and potential of players in FIFA 21')
plt.xlabel('Rating and Potential')
plt.ylabel('Number of Players');

# %%
top_clubs_df = fifa_df['team'].value_counts().head(10)

# %%
high_cb_df
# Out:
#                  name  nationality  overall  age                  team
# 3     Virgil van Dijk  Netherlands       91   29            Liverpool
# 21       Sergio Ramos        Spain       89   34          Real Madrid
# 25  Kalidou Koulibaly      Senegal       88   29               Napoli
# 33              Piqué        Spain       88   33         FC Barcelona
# 34  Giorgio Chiellini        Italy       88   35             Juventus
# 37    Aymeric Laporte       France       87   26      Manchester City
# 49        Diego Godín      Uruguay       87   34                Inter
# 50       Mats Hummels      Germany       87   31    Borussia Dortmund
# 54       Thiago Silva       Brazil       87   35  Paris Saint-Germain
# 56     Milan Škriniar     Slovakia       86   25                Inter

# %%
plt.figure(figsize = (15,5))
sns.barplot(x = 'name', y = 'overall', data = high_cb_df);

# %%
plt.figure(figsize = (10,6))
sns.barplot(y = 'name', x = 'overall', data = high_st_df);

# %%
plt.figure(figsize = (8,5))
sns.set_color_codes("muted")
sns.barplot(y = 'name', x = 'overall', data = high_gk_df, color = 'b');

# %%
plt.figure(figsize = (10,6))
sns.barplot(fifa_df['overall'], fifa_df['age'])
plt.title('Overall vs Age', fontsize = 20)
plt.show()

# %%
high_team_rating = fifa_df.groupby('team')[['overall', 'potential']].max()

# %%
high_team_overall = high_team_rating.sort_values('overall', ascending = False).head(10)

# %%
high_team_overall
# Out:
#                       overall  potential
# team
# FC Barcelona               94         94
# Juventus                   93         93
# Paris Saint-Germain        92         95
# Manchester City            91         91
# Liverpool                  91         92
# FC Bayern München          91         91
# Real Madrid                91         92
# Atlético Madrid            91         93
# Tottenham Hotspur          89         91
# Chelsea                    89         89

# %%
high_team_overall.plot.bar();
plt.title('Clubs with highest overall vs potential rating in FIFA 21')
plt.xlabel('Team')
plt.ylabel('Ratings')
plt.legend(['Overall', 'Potential']);

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Please enter your API key ( from https://jovian.ml/ ):
# API KEY: ········
# [jovian] Updating notebook "trnjit27/fifa-21-data-course-project" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/trnjit27/fifa-21-data-course-project
# 'https://jovian.ml/trnjit27/fifa-21-data-course-project'

# %%
top_clubs_df
# Out:
# Free Agents            211
# River Plate             35
# FC Barcelona            33
# Everton                 33
# Olympique Lyonnais      33
# Newcastle United        33
# Valencia CF             33
# Villarreal CF           33
# Manchester United       33
# Liverpool               33
# Name: team, dtype: int64

# %%
plt.figure(figsize = (14,6))
top_clubs_df.plot.bar(color = 'green')
plt.title('Clubs with most players in FIFA 21')
plt.xlabel('Clubs')
plt.ylabel('Number of Players');

# %%
fifa_df.loc[0:2]
# Out:
#    player_id               name nationality  position  overall  age  hits  \
# 0     158023       Lionel Messi   Argentina  ST|CF|RW       94   33   299
# 1      20801  Cristiano Ronaldo    Portugal     ST|LW       93   35   276
# 2     190871          Neymar Jr      Brazil    CAM|LW       92   28   186
#
#    potential                  team
# 0         94         FC Barcelona
# 1         93             Juventus
# 2         92  Paris Saint-Germain

# %%
mnr_df = fifa_df.loc[0:2]
mnr_df
# Out:
#    player_id               name nationality  position  overall  age  hits  \
# 0     158023       Lionel Messi   Argentina  ST|CF|RW       94   33   299
# 1      20801  Cristiano Ronaldo    Portugal     ST|LW       93   35   276
# 2     190871          Neymar Jr      Brazil    CAM|LW       92   28   186
#
#    potential                  team
# 0         94         FC Barcelona
# 1         93             Juventus
# 2         92  Paris Saint-Germain

# %%
plt.bar(mnr_df.name, mnr_df.overall, width = 0.5,color = ['Red', 'Green', 'Blue']);

# %%
max_rating = fifa_df.groupby('nationality')['overall'].max().sort_values(ascending = False).head(10)

# %%
max_rating
# Out:
# nationality
# Argentina      94
# Portugal       93
# Brazil         92
# Belgium        91
# Netherlands    91
# Slovenia       91
# Poland         91
# Senegal        90
# Egypt          90
# Germany        90
# Name: overall, dtype: int64

# %%
max_rating.plot.bar(color = 'brown')
# Out:
# <AxesSubplot:xlabel='nationality'>
